# %%
#import required python packages
import pandas as pd
import numpy as np
import glob,os
import matplotlib.dates as mdates

#to plot in the notebook
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sn

#download the data and import into df
import pandas_datareader as pdr
from datetime import datetime
import statsmodels.regression.linear_model as rg
#import arch.unitroot as at

# %% [markdown]
# We need to extract various types of Crypto Currencies for this project. The best ones can be found from the source given below various Cryptocurrencies are taken into the dataframes using pandas_datareader.
#
# Source: https://finance.yahoo.com/news/top-10-cryptocurrencies-market-capitalisation-160046487.html
#
# The above article analyses the top 10 cryptocurrencies by market capitalisation.
#
# Beginning with the largest, the top 10 are currently Bitcoin ($BTC), Ethereum ($ETH), XRP ($XRP), Tether ($USDT), Bitcoin Cash ($BCH) , Litecoin ($LTC), EOS ($EOS), Binance Coin ($BNB), Bitcoin SV ($BSV) and Tezos ($XTZ).
#
# Bitcoin (BTC) $128bn
#
# Ethereum (ETH) $19.4bn
#
# XRP (XRP) $8.22bn
#
# Tether (USDT) $6.4bn
#
# Bitcoin Cash (BCH) $4.1bn
#
# Bitcoin SV (BSV) $3.4bn
#
# Litecoin (LTC) $2.6bn
#
# EOS (EOS) $2.4bn
#
# Binance Coin (BNB) $2.4bn
#
# Tezos (XTZ) $1.5bn

# %%
## Downloading and assembling the data for the project 

curr = ['BTC-USD','ETH-USD','XRP-USD','BCH-USD','USDT-USD','BSV-USD', 'LTC-USD','EOS-USD','BNB-USD','XTZ-USD']

BTC = pdr.get_data_yahoo(symbols='BTC-USD', start=datetime(2019, 1, 1), end=datetime(2020, 9, 1))
ETH = pdr.get_data_yahoo(symbols='ETH-USD', start=datetime(2019, 1, 1), end=datetime(2020, 9, 1))
XRP = pdr.get_data_yahoo(symbols='XRP-USD', start=datetime(2019, 1, 1), end=datetime(2020, 9, 1))
BCH = pdr.get_data_yahoo(symbols='BCH-USD', start=datetime(2019, 1, 1), end=datetime(2020, 9, 1))
USDT = pdr.get_data_yahoo(symbols='USDT-USD', start=datetime(2019, 1, 1), end=datetime(2020, 9, 1))
LTC = pdr.get_data_yahoo(symbols='LTC-USD', start=datetime(2019, 1, 1), end=datetime(2020, 9, 1))
EOS = pdr.get_data_yahoo(symbols='EOS-USD', start=datetime(2019, 1, 1), end=datetime(2020, 9, 1))
BNB = pdr.get_data_yahoo(symbols='BNB-USD', start=datetime(2019, 1, 1), end=datetime(2020, 9, 1))

data= pd.concat([BTC['Adj Close'],ETH['Adj Close']], ignore_index=True,axis=1)
data= pd.concat([data,XRP['Adj Close']], ignore_index=True,axis=1)
data= pd.concat([data,BCH['Adj Close']], ignore_index=True,axis=1)
data= pd.concat([data,USDT['Adj Close']], ignore_index=True,axis=1)
data= pd.concat([data,LTC['Adj Close']], ignore_index=True,axis=1)
data= pd.concat([data,EOS['Adj Close']], ignore_index=True,axis=1)
data= pd.concat([data,BNB['Adj Close']], ignore_index=True,axis=1)


data.columns = [ 'BTC_ADJ','ETH_ADJ','XRP_ADJ','BCH_ADJ','USDT_ADJ','LTC_ADJ','EOS_ADJ','BNB_ADJ']

data.head()
# Out:
#                 BTC_ADJ     ETH_ADJ   XRP_ADJ     BCH_ADJ  USDT_ADJ  \
# Date
# 2019-01-01  3843.520020  140.819412  0.364771  164.854599  1.018335
# 2019-01-02  3943.409424  155.047684  0.375243  171.827377  1.024012
# 2019-01-03  3836.741211  149.135010  0.360224  162.049927  1.019473
# 2019-01-04  3857.717529  154.581940  0.356747  161.395630  1.017200
# 2019-01-05  3845.194580  155.638596  0.355275  160.401215  1.018489
#
#               LTC_ADJ   EOS_ADJ   BNB_ADJ
# Date
# 2019-01-01  31.979931  2.663533  6.075273
# 2019-01-02  33.433681  2.887629  6.188613
# 2019-01-03  32.026699  2.681411  5.903534
# 2019-01-04  32.404167  2.721645  6.065138
# 2019-01-05  34.936867  2.699467  6.065543

# %%
# We need to normalize the values to project them on a visualization plot for better understanding of the datd

prices_norm = data.divide(data.iloc[0])

curr = ['BTC_ADJ','ETH_ADJ','XRP_ADJ','BCH_ADJ','USDT_ADJ','LTC_ADJ','EOS_ADJ','BNB_ADJ']

plt.figure(figsize=(16,8))
plt.xticks(rotation=45)
ax = plt.axes()
plt.plot(prices_norm)
plt.title('Change of value of cryptocurrencies overtime')
plt.legend(curr)
plt.xlabel("Date")
plt.gca().xaxis.set_major_formatter(mdates.DateFormatter('%Y-%m-%d'))
ax.grid(True)

plt.show()
# Out:
# C:\Users\Owner\Anaconda3\lib\site-packages\ipykernel_launcher.py:10: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   # Remove the CWD from sys.path while we load stuff.

# %% [markdown]
# We can observe that some currencies performed well compared to others. Almost all the currencies values fell when the Corona Pandemic started in March in USA. But later in August this year all the currencies values increased drastically.

# %%
#Normalizing the dataframe and get percentage change values 
data=pd.DataFrame(data)

def normalize_series(data):
    #take tail to drop head NA
    return data.pct_change(1).dropna()
dt=normalize_series(data)

#remove first row with NAs
dt=dt.tail(len(dt)-1)
dt.columns = [ 'BTC_RET','ETH_RET','XRP_RET','BCH_RET','USDT_RET','LTC_RET','EOS_RET','BNB_RET']
dt['BTC_RET'].head()
# Out:
# Date
# 2019-01-03   -0.027050
# 2019-01-04    0.005467
# 2019-01-05   -0.003246
# 2019-01-06    0.060189
# 2019-01-07   -0.012605
# Name: BTC_RET, dtype: float64

# %%
# Normalizing and setting up cumulative returns in a  datafrme 
def normalize_and_accumulate_series(data):
    #take tail to drop head NA
    return data.pct_change(1).cumsum().dropna()
dt =normalize_and_accumulate_series(data)


#remove first row with NAs
dt = dt.tail(len(dt)-1)
dt.columns = [ 'BTC_C.RET','ETH_C.RET','XRP_C.RET','BCH_C.RET','USDT_C.RET','LTC_C.RET','EOS_C.RET','BNB_C.RET']
dt['BTC_C.RET'].head()
# Out:
# Date
# 2019-01-03   -0.001061
# 2019-01-04    0.004407
# 2019-01-05    0.001160
# 2019-01-06    0.061349
# 2019-01-07    0.048745
# Name: BTC_C.RET, dtype: float64

# %%
dt.describe()
# Out:
#         BTC_C.RET   ETH_C.RET   XRP_C.RET   BCH_C.RET  USDT_C.RET   LTC_C.RET  \
# count  609.000000  609.000000  609.000000  609.000000  609.000000  609.000000
# mean     0.904814    0.628704   -0.083711    0.918241   -0.011409    0.997695
# std      0.457848    0.452895    0.180980    0.496727    0.005471    0.358449
# min     -0.112581   -0.263528   -0.585540   -0.364046   -0.037983   -0.026396
# 25%      0.803548    0.313335   -0.183796    0.740115   -0.014215    0.836231
# 50%      1.025952    0.565637   -0.120629    1.042291   -0.011565    1.017841
# 75%      1.213278    0.923819    0.006147    1.250719   -0.008798    1.221324
# max      1.609882    1.900109    0.396866    1.690239    0.038708    1.734961
#
#         EOS_C.RET   BNB_C.RET
# count  609.000000  609.000000
# mean     0.681754    1.415027
# std      0.295588    0.461692
# min     -0.136845   -0.072997
# 25%      0.497019    1.247760
# 50%      0.718404    1.516974
# 75%      0.855066    1.720864
# max      1.384569    2.064472

# %%
# The Cummulative returns Plot to get the data based on rate of change

plt.figure(figsize=(16,8))
plt.xticks(rotation=45)
ax = plt.axes()
plt.plot(dt['BTC_C.RET'],label='BTC CUMMULATIVE RETURNS')
plt.plot(dt['ETH_C.RET'],label='ETH CUMMULATIVE RETURNS')
plt.plot(dt['XRP_C.RET'],label='XRP CUMMULATIVE RETURNS')
plt.plot(dt['BCH_C.RET'],label='BCH CUMMULATIVE RETURNS')
plt.plot(dt['USDT_C.RET'],label='USDT CUMMULATIVE RETURNS')
plt.plot(dt['LTC_C.RET'],label='LTC CUMMULATIVE RETURNS')
plt.plot(dt['EOS_C.RET'],label='EOS CUMMULATIVE RETURNS')
plt.plot(dt['BNB_C.RET'],label='BNB CUMMULATIVE RETURNS')
plt.xlabel("Date")
plt.gca().xaxis.set_major_formatter(mdates.DateFormatter('%Y-%m-%d'))
ax.grid(True)
plt.legend(loc='best')
plt.show()
# Out:
# C:\Users\Owner\Anaconda3\lib\site-packages\ipykernel_launcher.py:5: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   """

# %% [markdown]
# Two main criteria that would determine the desired pair are the correlation value and Cointegration. The pair with the highest correlation, is the desired pair. High positive correlation means that the returns of both currencies are going towards same direction. Conintegration values should be low for a desired value. values less than 0.05 are better.
#
# First we attempted to get the p-value of all possible pair in our selected

# %%
#obtaining the P-value for every possible pair within our selected
#for cointegration test 
from statsmodels.tsa.stattools import coint
import scipy

#co- integration test
for p1 in dt.columns:
    
    for p2 in dt.columns:
        
        if p1 != p2:
            test_result = coint(dt[p1], dt[p2])
            print(p1 + ' and ' + p2 + ': p-value = ' + str(test_result[1]))
            #rint(test_result)
# Out:
# BTC_C.RET and ETH_C.RET: p-value = 0.7786216015427649
# BTC_C.RET and XRP_C.RET: p-value = 0.6056744337125686
# BTC_C.RET and BCH_C.RET: p-value = 0.7183025600656374
# BTC_C.RET and USDT_C.RET: p-value = 0.8329322887310433
# BTC_C.RET and LTC_C.RET: p-value = 0.925062390185712
# BTC_C.RET and EOS_C.RET: p-value = 0.9071548416075506
# BTC_C.RET and BNB_C.RET: p-value = 0.6730362154781073
# ETH_C.RET and BTC_C.RET: p-value = 0.9791492051684467
# ETH_C.RET and XRP_C.RET: p-value = 0.9853796856043698
# ETH_C.RET and BCH_C.RET: p-value = 0.9633110178466165
# ETH_C.RET and USDT_C.RET: p-value = 0.975190971217533
# ETH_C.RET and LTC_C.RET: p-value = 0.9922523053043157
# ETH_C.RET and EOS_C.RET: p-value = 0.993387682627377
# ETH_C.RET and BNB_C.RET: p-value = 0.9164654694275776
# XRP_C.RET and BTC_C.RET: p-value = 0.3398700887745611
# XRP_C.RET and ETH_C.RET: p-value = 0.32085185099258917
# XRP_C.RET and BCH_C.RET: p-value = 0.38652548318453894
# XRP_C.RET and USDT_C.RET: p-value = 0.27039307141518953
# XRP_C.RET and LTC_C.RET: p-value = 0.0969295395363014
# XRP_C.RET and EOS_C.RET: p-value = 0.21565520504065117
# XRP_C.RET and BNB_C.RET: p-value = 0.18719458100654834
# BCH_C.RET and BTC_C.RET: p-value = 0.5762658764699249
# BCH_C.RET and ETH_C.RET: p-value = 0.8349696963143919
# BCH_C.RET and XRP_C.RET: p-value = 0.5265782501710377
# BCH_C.RET and USDT_C.RET: p-value = 0.741627407508859
# BCH_C.RET and LTC_C.RET: p-value = 0.8458855697311265
# BCH_C.RET and EOS_C.RET: p-value = 0.6943293701128654
# BCH_C.RET and BNB_C.RET: p-value = 0.21481084499859493
# USDT_C.RET and BTC_C.RET: p-value = 0.0006131164626125805
# USDT_C.RET and ETH_C.RET: p-value = 0.00034669084337769643
# USDT_C.RET and XRP_C.RET: p-value = 0.0003167387812527569
# USDT_C.RET and BCH_C.RET: p-value = 0.0006243028311772452
# USDT_C.RET and LTC_C.RET: p-value = 0.0001785468986298116
# USDT_C.RET and EOS_C.RET: p-value = 0.00031767770705852234
# USDT_C.RET and BNB_C.RET: p-value = 0.0007207740915642765
# LTC_C.RET and BTC_C.RET: p-value = 0.3974923900904414
# LTC_C.RET and ETH_C.RET: p-value = 0.6213018770586294
# LTC_C.RET and XRP_C.RET: p-value = 0.04853706510374466
# LTC_C.RET and BCH_C.RET: p-value = 0.6028637885858639
# LTC_C.RET and USDT_C.RET: p-value = 0.4822089411184612
# LTC_C.RET and EOS_C.RET: p-value = 0.04172354029524334
# LTC_C.RET and BNB_C.RET: p-value = 0.0559482226123722
# EOS_C.RET and BTC_C.RET: p-value = 0.3629729397524136
# EOS_C.RET and ETH_C.RET: p-value = 0.33975230543198437
# EOS_C.RET and XRP_C.RET: p-value = 0.06936346427466676
# EOS_C.RET and BCH_C.RET: p-value = 0.3026842960371712
# EOS_C.RET and USDT_C.RET: p-value = 0.4046605044759155
# EOS_C.RET and LTC_C.RET: p-value = 0.02765736723702266
# EOS_C.RET and BNB_C.RET: p-value = 0.042844553933918096
# BNB_C.RET and BTC_C.RET: p-value = 0.20714621818066747
# BNB_C.RET and ETH_C.RET: p-value = 0.0384519717819443
# BNB_C.RET and XRP_C.RET: p-value = 0.008001858451834131
# BNB_C.RET and BCH_C.RET: p-value = 0.06937187369762121
# BNB_C.RET and USDT_C.RET: p-value = 0.4750954033168114
# BNB_C.RET and LTC_C.RET: p-value = 0.07828352267445264
# BNB_C.RET and EOS_C.RET: p-value = 0.06639066081990122
